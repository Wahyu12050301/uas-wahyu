# %%
import os
import csv
import base64
import requests
import random
from difflib import SequenceMatcher
from PIL import Image
from io import BytesIO

# %%
# Konfigurasi
LMSTUDIO_API_URL = "http://127.0.0.1:1234/v1/chat/completions"
SELECTED_MODEL_NAME = "google/gemma-3-4b"
DATASET_DIR = "C:\\Users\\User\\OneDrive\\Documents\\uas wahyu\\test"
LABEL_CSV = "label.csv"
OUTPUT_CSV = "results/ocr_predictions.csv"

# %%
# Variasi Prompt (anti-copy strategy)
PROMPT_VARIANTS = [
    "Tolong baca dan sebutkan nomor polisi kendaraan dari gambar ini. Jawaban hanya berupa isi nomor plat tanpa tambahan kata lainnya.",
    "Silakan ekstrak teks nomor plat kendaraan dari gambar ini, dan hanya tuliskan nomor plat-nya.",
    "Apa isi dari nomor plat kendaraan yang tampak pada gambar? Jawaban harus langsung berupa nomor plat tersebut.",
    "Identifikasi teks pada plat kendaraan di gambar ini. Harap jawab dengan format nomor plat saja.",
    "Baca plat nomor kendaraan dalam gambar ini, lalu berikan hanya nomor plat-nya tanpa kata tambahan."
]

# %%
# Encode Gambar
def encode_image(image_path):
    img = Image.open(image_path)
    img = img.convert("RGB")
    img = img.resize((64, 64))  # Resize agar lebih ringan
    buffered = BytesIO()
    img.save(buffered, format="JPEG")
    return base64.b64encode(buffered.getvalue()).decode("utf-8")

# %%
# Hitung CER
def calculate_cer(pred, truth):
    matcher = SequenceMatcher(None, truth, pred)
    edits = 0
    for tag, i1, i2, j1, j2 in matcher.get_opcodes():
        if tag != 'equal':
            edits += max(i2 - i1, j2 - j1)
    return round(edits / max(len(truth), 1), 4)

# %%
# Load Label CSV
def load_ground_truth_from_csv(csv_path):
    gt_map = {}
    try:
        with open(csv_path, mode='r', encoding='utf-8') as file:
            reader = csv.reader(file)
            for row in reader:
                if len(row) >= 2 and "image" not in row[0].lower():
                    filename = os.path.basename(row[0]).strip()
                    label = row[1].strip().replace(" ", "").replace("-", "").upper()
                    gt_map[filename] = label
    except Exception as e:
        print(f"❌ Failed to read CSV: {e}")
    return gt_map

# %%
# Kirim Prompt dan Gambar ke LMStudio
def query_model(image_b64):
    prompt = random.choice(PROMPT_VARIANTS)  # Ambil prompt random

    payload = {
        "model": SELECTED_MODEL_NAME,
        "messages": [
            {
                "role": "user",
                "content": [
                    {"type": "text", "text": prompt},
                    {"type": "image_url", "image_url": {"url": f"data:image/jpeg;base64,{image_b64}"}}
                ]
            }
        ],
        "temperature": 0.2,
        "stream": False
    }

    headers = {"Content-Type": "application/json"}

    try:
        response = requests.post(LMSTUDIO_API_URL, json=payload, headers=headers, timeout=60)
        if response.status_code == 200:
            result = response.json()
            return result["choices"][0]["message"]["content"].strip()
        else:
            print(f"API Error: {response.status_code} - {response.text}")
            return "ERROR"
    except Exception as e:
        print(f"❌ Request failed: {e}")
        return "ERROR"

# %%
# Fungsi Utama
def main():
    if not os.path.exists(DATASET_DIR):
        print(f"❌ Dataset folder tidak ditemukan: {DATASET_DIR}")
        return

    os.makedirs("results", exist_ok=True)
    labels = load_ground_truth_from_csv(LABEL_CSV)

    with open(OUTPUT_CSV, "w", newline='', encoding='utf-8') as out_csv:
        writer = csv.writer(out_csv)
        writer.writerow(["image", "ground_truth", "prediction", "CER_score"])

        total, errors, scores = 0, 0, []

        for fname in sorted(os.listdir(DATASET_DIR)):
            if not fname.lower().endswith((".jpg", ".jpeg", ".png")):
                continue
            if fname not in labels:
                print(f"⚠️ No label for {fname}, skipped.")
                continue

            path = os.path.join(DATASET_DIR, fname)
            gt = labels[fname]
            print(f"📸 {fname}...")

            try:
                image_b64 = encode_image(path)
                pred = query_model(image_b64)
                pred = pred.replace(" ", "").replace("-", "").upper()
                cer = calculate_cer(pred, gt)
                writer.writerow([fname, gt, pred, cer])
                print(f"✅ GT: {gt} | Pred: {pred} | CER: {cer}")
                scores.append(cer)
                total += 1
            except Exception as e:
                print(f"❌ Error on {fname}: {e}")
                writer.writerow([fname, gt, "ERROR", 1.0])
                errors += 1

        if scores:
            avg = sum(scores) / len(scores)
            print(f"\n📈 Average CER: {avg:.4f}")
        print(f"\n🎉 Done! Processed: {total}, Errors: {errors}")


if __name__ == "__main__":
    main()
# Out:
# 📸 test001_1.jpg...
# ✅ GT: B9140BCD | Pred: S140BCD | CER: 0.25
# 📸 test001_2.jpg...
# ✅ GT: B2407UZO | Pred: B2407UZO | CER: 0.0
# 📸 test001_3.jpg...
# ✅ GT: B2642PKM | Pred: B2842PKM | CER: 0.125
# 📸 test002_1.jpg...
# ✅ GT: BG1352AE | Pred: 1352AE | CER: 0.25
# 📸 test003_1.jpg...
# ✅ GT: B2634UZF | Pred: B2634UZF | CER: 0.0
# 📸 test003_2.jpg...
# ✅ GT: B1995JVK | Pred: B1995JVK | CER: 0.0
# 📸 test004_1.jpg...
# ✅ GT: B9062VEH | Pred: XYZ1234 | CER: 0.875
# 📸 test005_1.jpg...
# ✅ GT: DD3798KM | Pred: DD798 | CER: 0.375
# 📸 test006_1.jpg...
# ✅ GT: T1329KC | Pred: 1329KC | CER: 0.1429
# 📸 test007_1.jpg...
# ✅ GT: AD8865EE | Pred: AD865EE | CER: 0.125
# 📸 test008_1.jpg...
# ✅ GT: DK1157AAB | Pred: DK1157AAB | CER: 0.0
# 📸 test008_2.jpg...
# ✅ GT: AA1997FE | Pred: 1997FE | CER: 0.25
# 📸 test009_1.jpg...
# ✅ GT: H8518NA | Pred: H0518NA | CER: 0.1429
# 📸 test009_2.jpg...
# ✅ GT: K1649GB | Pred: KC1649GB | CER: 0.1429
# 📸 test010_1.jpg...
# ✅ GT: B9416PCN | Pred: B9416PCN | CER: 0.0
# 📸 test010_2.jpg...
# ✅ GT: H1147UY | Pred: H147UY | CER: 0.1429
# 📸 test011_1.jpg...
# ✅ GT: H1691IL | Pred: H1691IL | CER: 0.0
# 📸 test011_2.jpg...
# ✅ GT: B9374RI | Pred: B83714 | CER: 0.5714
# 📸 test011_3.jpg...
# ✅ GT: D1204AIG | Pred: D1204AIG | CER: 0.0
# 📸 test012_1.jpg...
# ✅ GT: E1887BA | Pred: 18871 | CER: 0.4286
# 📸 test013_1.jpg...
# ✅ GT: B1439UZP | Pred: B1439UZP | CER: 0.0
# 📸 test013_2.jpg...
# ✅ GT: B1128W0S | Pred: B1128HOS | CER: 0.25
# 📸 test014_1.jpg...
# ✅ GT: B1388DFX | Pred: 1388DFX | CER: 0.125
# 📸 test015_1.jpg...
# ✅ GT: AD1898BT | Pred: AD1798BT | CER: 0.125
# 📸 test016_1.jpg...
# ✅ GT: E1517DQ | Pred: E151700 | CER: 0.2857
# 📸 test017_1.jpg...
# ✅ GT: AD8982FS | Pred: 8982FS | CER: 0.25
# 📸 test018_1.jpg...
# ✅ GT: L7603UA | Pred: 7603UA | CER: 0.1429
# 📸 test019_1.jpg...
# ✅ GT: AD7HS | Pred: AD7HS | CER: 0.0
# 📸 test019_2.jpg...
# ✅ GT: B1959WYK | Pred: 1959HYK | CER: 0.25
# 📸 test020_1.jpg...
# ✅ GT: AG8634EK | Pred: AG8694LK | CER: 0.25
# 📸 test020_2.jpg...
# ✅ GT: AD1329PY | Pred: AD1328PY | CER: 0.125
# 📸 test021_1.jpg...
# ✅ GT: BA1709DW | Pred: BA1709DN | CER: 0.125
# 📸 test021_2.jpg...
# ✅ GT: W1236VZ | Pred: W1236VZ | CER: 0.0
# 📸 test022_1.jpg...
# ✅ GT: W1825OZ | Pred: 182507Z | CER: 0.4286
# 📸 test022_2.jpg...
# ✅ GT: L1202UE | Pred: L1202UE | CER: 0.0
# 📸 test022_3.jpg...
# ✅ GT: L3823IB | Pred: 3823100226 | CER: 1.0
# 📸 test023_1.jpg...
# ✅ GT: B1730JLO | Pred: B1730JLO | CER: 0.0
# 📸 test024_1.jpg...
# ✅ GT: B2964TRU | Pred: B2964 | CER: 0.375
# 📸 test025_1.jpg...
# ✅ GT: S5585LP | Pred: 5585LP | CER: 0.1429
# 📸 test025_2.jpg...
# ✅ GT: L2858RR | Pred: L2858RA | CER: 0.1429
# 📸 test025_3.jpg...
# ✅ GT: W1185ZO | Pred: 1165Z0 | CER: 0.4286
# 📸 test025_4.jpg...
# ✅ GT: 9840VU | Pred: 9840VU | CER: 0.0
# 📸 test026_1.jpg...
# ✅ GT: N9652DF | Pred: 9652 | CER: 0.4286
# 📸 test026_2.jpg...
# ✅ GT: L3836ZX | Pred: 3836ZX | CER: 0.1429
# 📸 test027_1.jpg...
# ✅ GT: N1905IG | Pred: N1905IG | CER: 0.0
# 📸 test027_2.jpg...
# ✅ GT: B1109CLR | Pred: 1169CLR | CER: 0.25
# 📸 test027_3.jpg...
# ✅ GT: L1840AA | Pred: 1840A | CER: 0.2857
# 📸 test028_1.jpg...
# ✅ GT: L1438EO | Pred: 1438E0 | CER: 0.2857
# 📸 test028_2.jpg...
# ✅ GT: 1436AAA | Pred: L1436AAA | CER: 0.1429
# 📸 test029_1.jpg...
# ✅ GT: W1518WF | Pred: W1516 | CER: 0.4286
# 📸 test029_2.jpg...
# ✅ GT: G1986N | Pred: 1986H | CER: 0.3333
# 📸 test029_3.jpg...
# ✅ GT: L1588OO | Pred: 158800 | CER: 0.4286
# 📸 test029_4.jpg...
# ✅ GT: L1436AAA | Pred: L1436AAA | CER: 0.0
# 📸 test030_1.jpg...
# ✅ GT: S8062NF | Pred: S8062HF | CER: 0.1429
# 📸 test030_2.jpg...
# ✅ GT: G1894TE | Pred: 1894 | CER: 0.4286
# 📸 test031_1.jpg...
# ✅ GT: L1560JQ | Pred: L1560JO | CER: 0.1429
# 📸 test031_2.jpg...
# ✅ GT: L1568Q0 | Pred: L156808 | CER: 0.2857
# 📸 test031_3.jpg...
# ✅ GT: L1932AAZ | Pred: 1332AA7 | CER: 0.375
# 📸 test032_1.jpg...
# ✅ GT: B2754SKY | Pred: B2754 | CER: 0.375
# 📸 test032_2.jpg...
# ✅ GT: W1192K | Pred: 1192 | CER: 0.3333
# 📸 test033_1.jpg...
# ✅ GT: L4561VK | Pred: 4561VK | CER: 0.1429
# 📸 test033_2.jpg...
# ✅ GT: L2693GA | Pred: 2693 | CER: 0.4286
# 📸 test033_3.jpg...
# ✅ GT: W9847G | Pred: 46412 | CER: 1.1667
# 📸 test033_4.jpg...
# ✅ GT: L1762ABJ | Pred: 1762ABJ | CER: 0.125
# 📸 test034_1.jpg...
# ✅ GT: L1811SU | Pred: 18111 | CER: 0.4286
# 📸 test034_2.jpg...
# ✅ GT: W1167V0 | Pred: 1167 | CER: 0.4286
# 📸 test034_3.jpg...
# ✅ GT: S61310CF | Pred: 61312ACE | CER: 0.5
# 📸 test034_4.jpg...
# ✅ GT: L2570AAD | Pred: L2570AAD | CER: 0.0
# 📸 test035_1.jpg...
# ✅ GT: L9643NN | Pred: 9643 | CER: 0.4286
# 📸 test035_2.jpg...
# ✅ GT: L5247GI | Pred: 5267GI1225 | CER: 0.8571
# 📸 test035_3.jpg...
# ✅ GT: L2498AAM | Pred: 2498AAH | CER: 0.25
# 📸 test035_4.jpg...
# ✅ GT: W1696YO | Pred: 1696YO | CER: 0.1429
# 📸 test036_1.jpg...
# ✅ GT: B1231JJA | Pred: 1231JJ4 | CER: 0.25
# 📸 test036_2.jpg...
# ✅ GT: B1618UAE | Pred: B1618UAE | CER: 0.0
# 📸 test037_1.jpg...
# ✅ GT: L1775V0 | Pred: 1775V8 | CER: 0.2857
# 📸 test037_2.jpg...
# ✅ GT: L300RX | Pred: L300RX | CER: 0.0
# 📸 test037_3.jpg...
# ✅ GT: L1879VG | Pred: 1879LC | CER: 0.4286
# 📸 test038_1.jpg...
# ✅ GT: D1523YCN | Pred: D1523YCH | CER: 0.125
# 📸 test038_2.jpg...
# ✅ GT: L1877ACU | Pred: 1877ACU | CER: 0.125
# 📸 test039_1.jpg...
# ✅ GT: L1069VK | Pred: 1059VY | CER: 0.4286
# 📸 test040_1.jpg...
# ✅ GT: S1595LL | Pred: 1595LL | CER: 0.1429
# 📸 test041_1.jpg...
# ✅ GT: B1231JJA | Pred: 123JJJA | CER: 0.25
# 📸 test042_1.jpg...
# ✅ GT: AD1174SF | Pred: AD174SF | CER: 0.125
# 📸 test043_1.jpg...
# ✅ GT: W1898YW | Pred: 1898 | CER: 0.4286
# 📸 test043_2.jpg...
# ✅ GT: W1470PG | Pred: W1470PG | CER: 0.0
# 📸 test044_1.jpg...
# ✅ GT: L1930KF | Pred: 1930KF | CER: 0.1429
# 📸 test044_2.jpg...
# ✅ GT: N1004HE | Pred: 1004HE | CER: 0.1429
# 📸 test045_1.jpg...
# ✅ GT: S1347LJ | Pred: S1347LJ | CER: 0.0
# 📸 test046_1.jpg...
# ✅ GT: L1470ABK | Pred: 1470ABK | CER: 0.125
# 📸 test046_2.jpg...
# ✅ GT: L1265MX | Pred: 1265HX | CER: 0.2857
# 📸 test047_1.jpg...
# ✅ GT: N1524SY | Pred: 1524 | CER: 0.4286
# 📸 test047_2.jpg...
# ✅ GT: L1678ACE | Pred: 1678ACE | CER: 0.125
# 📸 test048_1.jpg...
# ✅ GT: L9316BC | Pred: 9316BC | CER: 0.1429
# 📸 test048_2.jpg...
# ✅ GT: W1838AY | Pred: 1838 | CER: 0.4286
# 📸 test049_1.jpg...
# ✅ GT: N1376DE | Pred: 1376 | CER: 0.4286
# 📸 test049_2.jpg...
# ✅ GT: N79AP | Pred: 792LP | CER: 0.6
# 📸 test050_1.jpg...
# ✅ GT: L1265OF | Pred: 1265OF | CER: 0.1429
# 📸 test050_2.jpg...
# ✅ GT: N1095G | Pred: N1095G | CER: 0.0
#
# 📈 Average CER: 0.2404
#
# 🎉 Done! Processed: 98, Errors: 0
